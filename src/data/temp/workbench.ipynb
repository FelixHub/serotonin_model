# %%
import pandas as pd
from handlers import BehaviorDataHandler, PhotometryDataHandler
from helpers import (
    sync_behavior_data_to_photometry,
    get_gain_change_events,
    extract_data_of_interest,
)

# Instantiate data handlers
behavior_handler = BehaviorDataHandler()
photometry_handler = PhotometryDataHandler()

# %%
# Initialize an empty DataFrame to concatenate all the data
df_plot_all = []
window = (30, 80)

# for behavior_file, photometry_file in zip(behavior_handler.csv_files, photometry_handler.csv_files):

behavior_file = behavior_handler.csv_files[8]
photometry_file = photometry_handler.csv_files[8]

# Process the data
behavior_data = behavior_handler.process(behavior_file)
photometry_data = photometry_handler.process(photometry_file)

# Sync behavior data to photometry
synced_behavior_data = sync_behavior_data_to_photometry(behavior_data, photometry_data)

# Get gain change events
gain_change_events = get_gain_change_events(synced_behavior_data)

# Extract data of interest
df_plot = extract_data_of_interest(gain_change_events, photometry_data, window);

df_plot_all.append(df_plot)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/serotonin/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/mambaforge/envs/serotonin/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/mambaforge/envs/serotonin/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 12
#      10 # Process the data
#      11 behavior_data = behavior_handler.process(behavior_file)
# ---> 12 photometry_data = photometry_handler.process(photometry_file)
#      14 # Sync behavior data to photometry
#      15 synced_behavior_data = sync_behavior_data_to_photometry(behavior_data, photometry_data)
#
# File ~/CCN-Pouget Dropbox/Nisheet Patel/Documents/Projects/serotonin_model/src/data/handlers.py:105, in PhotometryDataHandler.process(self, file)
#     102 def process(self, file) -> pd.DataFrame:
#     103     return (
#     104         pd.read_csv(file)
# --> 105         .pipe(self._extract_dF_over_F, file)
#     106         .pipe(self.append_metadata_columns, file)
#     107     )
#
# File ~/mambaforge/envs/serotonin/lib/python3.11/site-packages/pandas/core/generic.py:5926, in NDFrame.pipe(self, func, *args, **kwargs)
#    5924 if using_copy_on_write():
#    5925     return common.pipe(self.copy(deep=None), func, *args, **kwargs)
# -> 5926 return common.pipe(self, func, *args, **kwargs)
#
# File ~/mambaforge/envs/serotonin/lib/python3.11/site-packages/pandas/core/common.py:518, in pipe(obj, func, *args, **kwargs)
#     516     return func(*args, **kwargs)
#     517 else:
# --> 518     return func(obj, *args, **kwargs)
#
# File ~/CCN-Pouget Dropbox/Nisheet Patel/Documents/Projects/serotonin_model/src/data/handlers.py:228, in PhotometryDataHandler._extract_dF_over_F(self, df, file)
#     226 ax[1].set_ylabel("GCaMP delta-F/F (%)")
#     227 ax[1].set_title("GCaMP dF/F First 100 seconds")
# --> 228 ax[1].set_xlim(sample_times_470[0], sample_times_470[0] + 100)
#     229 plt.savefig(photometry_folder + "/final_dF_over_F_new.png")
#     230 plt.close()
#
# File ~/mambaforge/envs/serotonin/lib/python3.11/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/mambaforge/envs/serotonin/lib/python3.11/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~/mambaforge/envs/serotonin/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 0

# %%
synced_behavior_data = sync_behavior_data_to_photometry(behavior_data, photometry_data)
synced_behavior_data
# Out:
# Synced behavior to photometry for RL2, 1, 20220307
# Empty DataFrame
# Columns: [Timestamp, WheelPosition, RunningSpeed, Reward, Gain, TrialNumber, mouse_id, training_group, session_date]
# Index: []

# %%
# Concatenate the data
df_plot_all = pd.concat(df_plot_all, ignore_index=True)

# switch type of column
df_plot_all["gain_change"] = df_plot_all["gain_change"].astype('category')
df_plot_all["gain_change"].cat.reorder_categories(['++', '+', '0', '-', '--'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 990    -
# 991    -
# 992    -
# 993    -
# 994    -
# Name: gain_change, Length: 995, dtype: category
# Categories (5, object): ['++', '+', '0', '-', '--']

# %%
df_plot
# Out:
#       Timestamp  df_over_f  mouse_id training_group session_date  magnitude
# 0     -0.966624  -0.000651         1            RL1     20220114        0.0  \
# 1     -0.933280  -0.000038         1            RL1     20220114        0.0
# 2     -0.899968   0.001127         1            RL1     20220114        0.0
# 3     -0.866624   0.002376         1            RL1     20220114        0.0
# 4     -0.833280   0.003077         1            RL1     20220114        0.0
# ...         ...        ...       ...            ...          ...        ...
# 1993   2.566624   0.000008         1            RL1     20220114       -2.0
# 1994   2.599936  -0.000246         1            RL1     20220114       -2.0
# 1995   2.633280  -0.000465         1            RL1     20220114       -2.0
# 1996   2.666592  -0.000637         1            RL1     20220114       -2.0
# 1997   2.699936  -0.000788         1            RL1     20220114       -2.0
#
#      gain_change  delta_position  phase_shift  gain_before  gain_after
# 0              0       10.464365   226.030279          0.3         0.3
# 1              0       10.464365   226.030279          0.3         0.3
# 2              0       10.464365   226.030279          0.3         0.3
# 3              0       10.464365   226.030279          0.3         0.3
# 4              0       10.464365   226.030279          0.3         0.3
# ...          ...             ...          ...          ...         ...
# 1993           -       15.726319   339.688488          3.0         1.0
# 1994           -       15.726319   339.688488          3.0         1.0
# 1995           -       15.726319   339.688488          3.0         1.0
# 1996           -       15.726319   339.688488          3.0         1.0
# 1997           -       15.726319   339.688488          3.0         1.0
#
# [1998 rows x 11 columns]

# %%
# Plot the data
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(data=df_plot, x="Timestamp", y="df_over_f", hue="gain_change")
plt.show()
